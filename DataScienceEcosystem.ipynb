# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:248cf35c-b4e7-4c52-aca8-05bdd7d1485c.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# ![3-intro.png](attachment:ca25d3f8-c80d-4b6b-8f63-822f9ebd8f50.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# ![螢幕截圖 2024-08-05 下午3.48.43.png](attachment:e21ac08c-658e-48aa-a9d4-61cfe55cabeb.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# ![5-dslibraries.png](attachment:31c3b24d-6272-45e3-9a0d-f6c50b1ba04e.png)

# %% [markdown]
# Data Science Tools
# Jupyter Notebook
# RStudio
# VScode

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives
# List popular languages for Data Science
# List commonly used libraries in Data Science
# List open source tools used in Data Science
# Demonstrate simple arithmetic expressions in Python

# %% [markdown]
# ## Author
# Wyman
